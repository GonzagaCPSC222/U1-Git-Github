# %% [markdown]
# # [CPSC 222](https://github.com/GonzagaCPSC3222) Intro to Data Science
# [Gonzaga University](https://www.gonzaga.edu/)
#
# [Gina Sprint](http://cs.gonzaga.edu/faculty/sprint/)
# # Github Classroom Submission Guide
#
# What are our learning objectives for this lesson?
# * Submit an assignment via Github Classroom
#
# Content used in this lesson is based upon information in the following sources:
# * [Github Classroom](https://classroom.github.com/)

# %% [markdown]
# ## GitHub Classroom Submission Guide
# Please see the Guide [here](https://docs.google.com/document/d/183lNT5ZUJlLjgBDwF2kmCo1-GzhhIL4PmMvPjaUWzDc/edit?usp=sharing)
